# %% [markdown]
# # Basic Prompt Structures Tutorial
#
# ## Overview
#
# This tutorial focuses on two fundamental types of prompt structures:
# 1. Single-turn prompts
# 2. Multi-turn prompts (conversations)
#
# We'll use OpenAI's GPT model and LangChain to demonstrate these concepts.
#
# ## Motivation
#
# Understanding different prompt structures is crucial for effective communication with AI models. Single-turn prompts are useful for quick, straightforward queries, while multi-turn prompts enable more complex, context-aware interactions. Mastering these structures allows for more versatile and effective use of AI in various applications.
#
# ## Key Components
#
# 1. **Single-turn Prompts**: One-shot interactions with the language model.
# 2. **Multi-turn Prompts**: Series of interactions that maintain context.
# 3. **Prompt Templates**: Reusable structures for consistent prompting.
# 4. **Conversation Chains**: Maintaining context across multiple interactions.
#
# ## Method Details
#
# We'll use a combination of OpenAI's API and LangChain library to demonstrate these prompt structures. The tutorial will include practical examples and comparisons of different prompt types.

# %% [markdown]
# ## Setup
#
# First, let's import the necessary libraries and set up our environment.

# %%
from langchain_core.messages import HumanMessage, SystemMessage, AIMessage
from langchain_ollama.llms import OllamaLLM
from langchain_core.prompts import ChatPromptTemplate  

history = []

def invoke_conversation(user_input):
    history.append(HumanMessage(content=user_input))
    response = llm.invoke(history)
    history.append(AIMessage(content=response))
    return response

llm = OllamaLLM(model="qwen2.5-coder:7b", temperature=0.7)
print("ready")
# Out:
# ready

# %% [markdown]
# ## 1. Single-turn Prompts
#
# Single-turn prompts are one-shot interactions with the language model. They consist of a single input (prompt) and generate a single output (response).

# %%
single_turn_prompt = "What are the three primary colors?"
print(llm.invoke(single_turn_prompt))
# Out:
# The three primary colors are red, green, and blue. These colors are considered primary because they cannot be produced by mixing other colors; instead, they are the fundamental colors from which all other colors can be created through various combinations and mixtures.

# %% [markdown]
# Now, let's use a PromptTemplate to create a more structured single-turn prompt:

# %%
structured_prompt = ChatPromptTemplate.from_template(
    template="Provide a brief explanation of {topic} and list its three main components."
)

chain = structured_prompt | llm
print(chain.invoke({"topic": "color theory"}))
# Out:
# Color theory is the study of colors and their relationships with one another. It encompasses principles such as how colors appear in different light conditions, how they interact with each other, and how they are used to evoke emotions or convey messages.
#
# The three main components of color theory include:
#
# 1. **Primary Colors**: These are the fundamental colors that cannot be created by mixing any other colors from the same set. For most color models, including the RGB (Red, Green, Blue) and CMYK (Cyan, Magenta, Yellow, Key or Black) systems used in digital displays and printing, the primary colors are Red, Blue, and Yellow.
#
# 2. **Secondary Colors**: These are created by mixing two primary colors. For example, mixing red and yellow produces orange, blue and yellow produce green, and red and blue produce violet (purple).
#
# 3. **Tertiary Colors**: These result from mixing a primary color with one of its adjacent secondary colors. Thus, there are six tertiary colors: three intermediate (between primary and secondary) like red-orange, yellow-green, and blue-violet; and three split-primary colors like red-crimson, blue-indigo, and green-teal.
#
# Understanding these components allows designers and artists to effectively use color in their work, enhancing aesthetics and conveying specific moods or messages through the visual presentation of color combinations.

# %% [markdown]
# ## 2. Multi-turn Prompts (Conversations)
#
# Multi-turn prompts involve a series of interactions with the language model, allowing for more complex and context-aware conversations.

# %%
history = []

print(invoke_conversation("Hi, I'm learning about space. Can you tell me about planets?"))
print(invoke_conversation("What's the largest planet in our solar system?"))
print(invoke_conversation("How does its size compare to Earth?"))
# Out:
# Hello! It's great that you're interested in learning about planets! Let's explore what we know about our solar system and beyond.
#
# ### Our Solar System
#
# Our solar system consists of the Sun, eight major planets, several dwarf planets, countless asteroids and comets, and a variety of other objects. Here are some of the key planets:
#
# 1. **Mercury**: The closest planet to the Sun, Mercury is known for its extreme temperature variations due to its proximity to the Sun. It has no atmosphere and is often referred to as the "Red Planet" because of its reddish appearance.
#
# 2. **Venus**: Venus is the second planet from the Sun and is often called Earth’s twin because it is similar in size and mass. However, it has a thick toxic atmosphere that traps heat, making it one of the hottest planets in our solar system.
#
# 3. **Earth**: Our home planet is unique because it supports life as we know it. It has liquid water on its surface, a breathable atmosphere, and a diverse range of ecosystems.
#
# 4. **Mars**: Known as the "Red Planet," Mars is famous for its red surface due to iron oxide (rust). It has polar ice caps, volcanoes, and canyons. The Red Planet has been explored by many robotic missions to search for signs of past or present life.
#
# 5. **Jupiter**: The largest planet in our solar system, Jupiter is a gas giant with a thick atmosphere mainly composed of hydrogen and helium. It has numerous moons and a prominent Great Red Spot—a giant storm that has been raging for hundreds of years.
#
# 6. **Saturn**: Saturn is known for its beautiful rings made of ice and rock particles. It also has many moons, including Titan, which has a thick atmosphere and lakes of liquid hydrocarbons.
#
# 7. **Uranus**: This gas giant is unique because it rotates on its side, causing extreme seasons as one hemisphere faces the Sun while the other faces away.
#
# 8. **Neptune**: Another gas giant, Neptune is known for its deep blue color due to methane in its atmosphere. It has a strong storm system called the Great Dark Spot.
#
# ### Beyond Our Solar System
#
# Beyond our solar system, we have discovered many planets orbiting other stars. These exoplanets are much more diverse than those in our solar system. Some key characteristics of exoplanets include:
#
# - **Habitable Zones**: These regions around a star where conditions might be suitable for liquid water to exist on the surface of a planet.
# - **Mass and Size**: Exoplanets can vary widely in mass and size, from rocky planets similar to Earth to gas giants as large as Jupiter.
# - **Atmospheres**: Some exoplanets have atmospheres that are similar to Earth’s, while others have thick, toxic atmospheres or no atmosphere at all.
#
# ### Key Concepts
#
# 1. **Planetary Formation**: Most theories of planetary formation suggest that they form from the accretion of dust and gas around a protostar.
# 2. **Orbital Dynamics**: The orbits of planets are determined by gravitational forces between the star and the planet. Kepler's laws describe these dynamics.
# 3. **Types of Planets**: Beyond the eight major planets, there are many other types of celestial bodies, including moons, asteroids, comets, and dwarf planets.
#
# Exploring the planets and their systems is a fascinating area of study in astronomy. Each discovery brings us closer to understanding our place in the universe and helps us explore the possibilities for life elsewhere. If you have any specific questions or areas you'd like to know more about, feel free to ask!
# The largest planet in our solar system is Jupiter. Here are some key facts about Jupiter:
#
# - **Size**: Jupiter is approximately 142,984 kilometers (88,846 miles) in diameter, which is more than 11 times the diameter of Earth.
#
# - **Mass**: It has a mass that is about 318 times greater than that of Earth. This massive size gives it a strong gravitational pull and allows it to hold a large number of moons.
#
# - **Composition**: Jupiter is primarily composed of hydrogen and helium, with small amounts of other elements mixed in. It is classified as a gas giant because it does not have a solid surface like the rocky planets.
#
# Jupiter's Great Red Spot is one of its most famous features, which is a giant storm that has been raging for at least 350 years. The planet also has numerous moons, with the four largest being Io, Europa, Ganymede, and Callisto, collectively known as the Galilean moons.
#
# Exploring Jupiter continues to be an important area of research in astronomy, offering insights into the formation and evolution of planets and potentially providing clues about the origins of our solar system.
# Jupiter is incredibly large compared to Earth. Here’s a direct comparison:
#
# - **Diameter**: Jupiter's diameter is approximately 142,984 kilometers (88,846 miles), while Earth's diameter is about 12,742 kilometers (7,918 miles). This means Jupiter is more than 11 times wider than Earth.
#
# - **Volume**: The volume of Jupiter is enormous. It is around 1,300 times greater than the volume of Earth.
#
# - **Surface Area**: Jupiter’s surface area is approximately 621 million square kilometers (238 million square miles), which is about 122 times larger than that of Earth.
#
# - **Mass**: Jupiter's mass is about 317.9 times that of Earth, making it the most massive planet in our solar system and more than twice as massive as all the other planets combined.
#
# In essence, if you could scale up Earth to match Jupiter's size while keeping all its features intact, it would be a tiny fraction of Jupiter’s true scale. This immense size is due to Jupiter’s enormous mass and gravitational pull, which allow it to hold a large number of moons and maintain its shape as a gas giant.

# %% [markdown]
# Let's compare how single-turn and multi-turn prompts handle a series of related questions:

# %%
history = []

# Single-turn prompts
prompts = [
    "What is the capital of France?",
    "What is its population?",
    "What is the city's most famous landmark?"
]

print("Single-turn responses:")
for prompt in prompts:
    print(f"Q: {prompt}")
    print(f"A: {llm.invoke(prompt)}\n")

# Multi-turn prompts
print("Multi-turn responses:")

for prompt in prompts:
    print(f"Q: {prompt}")
    print(f"A: {invoke_conversation(prompt)}\n")
# Out:
# Single-turn responses:
# Q: What is the capital of France?
# A: The capital of France is Paris.
#
# Q: What is its population?
# A: I'm sorry, but I don't have enough context to answer your question accurately. Could you please specify which entity or area you are referring to?
#
# Q: What is the city's most famous landmark?
# A: The city's most famous landmark is the Eiffel Tower.
#
# Multi-turn responses:
# Q: What is the capital of France?
# A: The capital of France is Paris.
#
# Q: What is its population?
# A: The current estimated population of Paris is around 2.1 million people.
#
# Q: What is the city's most famous landmark?
# A: The most famous landmark in Paris is the Eiffel Tower.

# %% [markdown]
# ## Conclusion
#
# This tutorial has introduced you to the basics of single-turn and multi-turn prompt structures. We've seen how:
#
# 1. Single-turn prompts are useful for quick, isolated queries.
# 2. Multi-turn prompts maintain context across a conversation, allowing for more complex interactions.
# 3. PromptTemplates can be used to create structured, reusable prompts.
# 4. Conversation chains in LangChain help manage context in multi-turn interactions.
#
# Understanding these different prompt structures allows you to choose the most appropriate approach for various tasks and create more effective interactions with AI language models.
